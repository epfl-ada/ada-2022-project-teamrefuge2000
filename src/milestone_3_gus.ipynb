# %% [markdown]
# ## Imports

# %%
import ast
import math

import requests
import urllib
import time

import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

from ast import literal_eval
from scipy import stats

import statsmodels.formula.api as smf
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Definitions of constants
#
# These are the constants for the data paths.

# %%
DATA_FOLDER           = "../data/"
PROCESSED_DATA_FOLDER = '../processed_data/'
CORENLP_DATA_FOLDER   = '../corenlp_plot_summaries/'

CHARACTER_DATASET     = DATA_FOLDER + "character.metadata.tsv"
MOVIE_DATASET         = DATA_FOLDER + "movie.metadata.tsv"
NAME_CLUSTER_DATASET  = DATA_FOLDER + "name.clusters.txt"
PLOT_DATASET          = DATA_FOLDER + "plot_summaries.txt"
TVTROPES_DATASET      = DATA_FOLDER + "tvtropes.clusters.txt"

PROCESSED_CHARACTER   = PROCESSED_DATA_FOLDER + 'character_metadata.csv'
PROCESSED_MOVIE       = PROCESSED_DATA_FOLDER + 'movie_metadata.csv'
PROCESSED_NAME        = PROCESSED_DATA_FOLDER + 'name_clusters.csv'
PROCESSED_PLOT        = PROCESSED_DATA_FOLDER + 'plot_summaries.csv'
PROCESSED_TVTROPES    = PROCESSED_DATA_FOLDER + 'tvtropes_clusters.csv'

# %% [markdown]
# # Step 1

# %% [markdown]
# ### 1.1 Pre-processing the data
#
# At first, we fetch the data from the `data` folder into pd dataframes in order to set the desired headings and to modify the type if needed.
# Then we store it in `processed_data` folder in the desired .csv format.

# %% [markdown]
# For `movie_metadata` and `character_metadata` we modify the dates to the datetime format.

# %%
movie_metadata = pd.read_csv(MOVIE_DATASET, sep='\t', header=None) \
    .rename(columns={0 : 'wikipedia_movie_id',
                     1 : 'freebase_movie_id',
                     2 : 'movie_name',
                     3 : 'movie_release_date',
                     4 : 'office_revenue',
                     5 : 'runtime',
                     6 : 'languages',
                     7 : 'countries',
                     8 : 'genres'})

movie_metadata['movie_release_date'] = pd.to_datetime(movie_metadata['movie_release_date'], errors = 'coerce')
movie_metadata['movie_release_year'] = movie_metadata['movie_release_date'].apply(lambda d : d.year)

# %%
character_metadata = pd.read_csv(CHARACTER_DATASET, sep='\t', header=None) \
    .rename(columns={0  : 'wikipedia_movie_id',
                     1  : 'freebase_movie_id',
                     2  : 'movie_release_date',
                     3  : 'character_name',
                     4  : 'actor_birth_date',
                     5  : 'actor_gender',
                     6  : 'actor_height',
                     7  : 'actor_ethnicity',
                     8  : 'actor_name',
                     9  : 'actor_age',
                     10 : 'freebase_map_id',
                     11 : 'freebase_character_id',
                     12 : 'freebase_actor_id'})

character_metadata['movie_release_date'] = pd.to_datetime(character_metadata['movie_release_date'],          errors='coerce')
character_metadata['actor_birth_date'] =   pd.to_datetime(character_metadata['actor_birth_date'], utc=True , errors='coerce')

# %%
plot_summaries = pd.read_csv(PLOT_DATASET, sep='\t', header=None)\
    .rename(columns={0 : 'movie_id',
                     1 : 'plot'})

# %%
name_clusters = pd.read_csv(NAME_CLUSTER_DATASET, sep='\t', header=None)\
    .rename(columns={0 : 'character_name',
                     1 : 'freebase_map_id'})

# %% [markdown]
# For the `tvtropes_cluster` : we first create a raw dataframe containing the data.
# Then we construct the resulting dataframe where each values of the dictionary correspond to the correct column.

# %%
tvtropes_cluster_raw = pd.read_csv(TVTROPES_DATASET, sep='\t', header=None)
tvtropes_cluster_raw[1] = tvtropes_cluster_raw[1].map(ast.literal_eval)
tvtropes_cluster = pd.DataFrame()

tvtropes_cluster['character_type'] = tvtropes_cluster_raw[0]
tvtropes_cluster['character_name'] = tvtropes_cluster_raw[1].map(lambda d : d['char'])
tvtropes_cluster['movie_name']     = tvtropes_cluster_raw[1].map(lambda d : d['movie'])
tvtropes_cluster['movie_id']       = tvtropes_cluster_raw[1].map(lambda d : d['id'])
tvtropes_cluster['actor_name']     = tvtropes_cluster_raw[1].map(lambda d : d['actor'])

# %% [markdown]
# Storing the cleaned data

# %%
character_metadata.to_csv(PROCESSED_CHARACTER, index=False)
movie_metadata    .to_csv(PROCESSED_MOVIE,     index=False)
plot_summaries    .to_csv(PROCESSED_PLOT,      index=False)
name_clusters     .to_csv(PROCESSED_NAME,      index=False)
tvtropes_cluster  .to_csv(PROCESSED_TVTROPES,  index=False)

# %% [markdown]
# ### 1.2 Creating the datasets

# %%
tmp = character_metadata.groupby(['wikipedia_movie_id', 'actor_gender']).size().unstack(fill_value=0)
tmp['number_actors'] = tmp['F'] + tmp['M']
tmp
# Out:
# actor_gender        F   M  number_actors
# wikipedia_movie_id
# 330                 4   0              4
# 3217                3  10             13
# 3333                6   8             14
# 3746                3  11             14
# 3837                2  18             20
# ...                ..  ..            ...
# 37322106            2   1              3
# 37373877            3   3              6
# 37476824            4   6             10
# 37478048            1   3              4
# 37501922            1   1              2
#
# [63652 rows x 3 columns]

# %%
#calculate the ratio of female actors for each movie

movie_gender = character_metadata.groupby(['wikipedia_movie_id', 'actor_gender']).size().unstack(fill_value=0)
movie_gender['women_ratio'] = movie_gender['F'] / (movie_gender['M'] + movie_gender['F'])
movie_gender['sex_diff'] = movie_gender['M'] - movie_gender['F']
movie_gender['number_actors'] = movie_gender['F'] + movie_gender['M']
movie_gender = movie_gender[['women_ratio', 'number_actors', 'sex_diff']].reset_index()

# %%
movie_gender
# Out:
# actor_gender  wikipedia_movie_id  women_ratio  number_actors  sex_diff
# 0                            330     1.000000              4        -4
# 1                           3217     0.230769             13         7
# 2                           3333     0.428571             14         2
# 3                           3746     0.214286             14         8
# 4                           3837     0.100000             20        16
# ...                          ...          ...            ...       ...
# 63647                   37322106     0.666667              3        -1
# 63648                   37373877     0.500000              6         0
# 63649                   37476824     0.400000             10         2
# 63650                   37478048     0.250000              4         2
# 63651                   37501922     0.500000              2         0
#
# [63652 rows x 4 columns]

# %% [markdown]
# Gender parity datasets

# %%
movie_information = ['wikipedia_movie_id', 'movie_release_date', 'movie_release_year', 'movie_name', 'office_revenue', 'countries', 'genres']
gender_parity = pd.merge(movie_gender, movie_metadata[movie_information], on='wikipedia_movie_id').dropna()

# %%
translate_countries = {
    'United States' : 'United States of America',
    'Hong Kong'                : 'Hong Kong, China (SAR)',
    'South Korea'              : 'Korea (Republic of)',
    'Korea'                    : 'Korea (Republic of)',
    'Russian Federation' : 'Russia',
    'Soviet Union' : 'Russia',
    'England' : 'United Kingdom',
    'Scotland' : 'United Kingdom',
    'Kingdom of Great Britain' : 'United Kingdom',
    'Czech Republic':'Czechia',
    'Iran (Islamic Republic of)' : 'Iran',
    'Slovak Republic' : 'Slovakia',
    'West Germany' : 'Germany',
    'Hong Kong, China (SAR)' : 'China',
    'Yugoslavia' : 'Slovenia',
    'Socialist Federal Republic of Yugoslavia' : 'Slovenia',
    'Bosnia and Herzegovina' : 'Bosnia and Herz.',
    'Serbia and Montenegro' : 'Serbia',
    'Viet Nam' : 'Vietnam',
    'Isle of Man' : 'United Kingdom'
}

# %%
gender_parity['countries'] = gender_parity['countries'].apply(lambda e : translate_countries.get(e,e))

# %% [markdown]
# Movie genre dataset

# %%
movie_genre_information = ['wikipedia_movie_id', 'movie_release_date', 'movie_name','genres']

movie_genre = pd.merge(movie_metadata[movie_genre_information].rename(columns={'wikipedia_movie_id' : 'movie_id'}), \
    plot_summaries, on='movie_id', how='inner').dropna()

#we are interested in the year only
movie_genre['year'] = pd.DatetimeIndex(movie_genre['movie_release_date']).year.astype('int')
movie_genre = movie_genre.drop(columns=['movie_release_date'])

#we convert the values of the genres dictionnaries to list
movie_genre['genres'] = movie_genre['genres'].apply(ast.literal_eval).apply(lambda x : set(x.values()))

# %% [markdown]
# # Step 2

# %% [markdown]
# ### C. Is there some variations in the box office revenue ?

# %%
#first by office revenue
movie_gender_office_revenue = gender_parity[['women_ratio','office_revenue']].\
    groupby('women_ratio')\
    .agg({'office_revenue' : 'mean'})

#make a mean by rolling windows to smooth up the function
movie_gender_office_revenue = movie_gender_office_revenue.rolling(window=30, min_periods=1, center=False).mean()
movie_gender_office_revenue = movie_gender_office_revenue.iloc[2:].reset_index()

#now we can plot a graph
movie_gender_office_revenue.plot(x='women_ratio', y='office_revenue', title="Mean office revenue in function of the women ratio") ;

# %% [markdown]
# ### Yes it appeared that the women_ratio does influence the mean office revenue of a film. But is it the only factor ? Are there more influencial factors ? For that we are going to do a linear regression with multiple factors.

# %%
def bootstrap_ci(data, ci=0.95):
    if len(data) > 10 :
        bootstrap_res = stats.bootstrap((data,), np.mean, confidence_level=ci)
        return bootstrap_res.confidence_interval
    else :
        return np.nan

# %%
def deconstruct_dict(df, col_name):
    df[col_name] = df[col_name] \
        .apply(ast.literal_eval).apply(lambda x : list(x.values()))
    df = df.apply(pd.Series.explode)\
        .reset_index().drop(columns=['index'])
    return df

# %%
linear_reg_df = gender_parity.copy()
linear_reg_df = deconstruct_dict(linear_reg_df, 'countries')
linear_reg_df = deconstruct_dict(linear_reg_df, 'genres')
linear_reg_df = linear_reg_df[['women_ratio', 'number_actors', 'movie_release_year', 'office_revenue', 'countries', 'genres', 'sex_diff']]

# %%
scaler = MinMaxScaler()
linear_reg_df[['women_ratio', 'number_actors', 'movie_release_year','sex_diff']] = scaler.fit_transform(linear_reg_df[['women_ratio', 'number_actors', 'movie_release_year','sex_diff']])

# %%
mod = smf.ols(formula='np.log(office_revenue) ~ women_ratio + movie_release_year + number_actors + C(genres) + C(countries)', data=linear_reg_df)

#adding a random seed ensures consistency
np.random.seed(42)
res = mod.fit()

print(res.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     np.log(office_revenue)   R-squared:                       0.276
# Model:                                OLS   Adj. R-squared:                  0.271
# Method:                     Least Squares   F-statistic:                     54.95
# Date:                    Fri, 23 Dec 2022   Prob (F-statistic):               0.00
# Time:                            00:26:33   Log-Likelihood:            -1.1721e+05
# No. Observations:                   57837   AIC:                         2.352e+05
# Df Residuals:                       57438   BIC:                         2.388e+05
# Df Model:                             398
# Covariance Type:                nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                   14.2825      0.697     20.480      0.000      12.916      15.649
# C(genres)[T.Acid western]                                   -3.4867      0.791     -4.406      0.000      -5.038      -1.936
# C(genres)[T.Action]                                          0.6061      0.247      2.454      0.014       0.122       1.090
# C(genres)[T.Action Comedy]                                   0.7294      0.299      2.440      0.015       0.143       1.315
# C(genres)[T.Action Thrillers]                                1.1858      0.268      4.418      0.000       0.660       1.712
# C(genres)[T.Action/Adventure]                                0.5805      0.248      2.343      0.019       0.095       1.066
# C(genres)[T.Addiction Drama]                                -0.7197      0.431     -1.671      0.095      -1.564       0.124
# C(genres)[T.Adult]                                          -0.0123      0.522     -0.023      0.981      -1.034       1.010
# C(genres)[T.Adventure]                                       0.7156      0.248      2.883      0.004       0.229       1.202
# C(genres)[T.Adventure Comedy]                                1.0732      0.305      3.521      0.000       0.476       1.671
# C(genres)[T.Airplanes and airports]                          1.1367      0.340      3.348      0.001       0.471       1.802
# C(genres)[T.Albino bias]                                     1.3116      0.607      2.162      0.031       0.122       2.501
# C(genres)[T.Alien Film]                                      1.0925      0.403      2.710      0.007       0.302       1.883
# C(genres)[T.Alien invasion]                                  0.0125      1.091      0.011      0.991      -2.127       2.152
# C(genres)[T.Americana]                                      -0.1031      0.333     -0.309      0.757      -0.756       0.550
# C(genres)[T.Animal Picture]                                  0.7035      0.321      2.190      0.029       0.074       1.333
# C(genres)[T.Animals]                                        -1.4233      1.859     -0.766      0.444      -5.066       2.220
# C(genres)[T.Animated Musical]                                1.0012      0.407      2.459      0.014       0.203       1.799
# C(genres)[T.Animated cartoon]                                0.6187      0.437      1.417      0.157      -0.237       1.475
# C(genres)[T.Animation]                                       0.5964      0.260      2.297      0.022       0.087       1.105
# C(genres)[T.Anime]                                          -0.0650      0.333     -0.195      0.845      -0.717       0.587
# C(genres)[T.Anthology]                                      -1.8723      0.792     -2.365      0.018      -3.424      -0.321
# C(genres)[T.Anthropology]                                   -2.0420      1.326     -1.540      0.123      -4.640       0.556
# C(genres)[T.Anti-war]                                        0.4607      0.416      1.107      0.268      -0.355       1.277
# C(genres)[T.Anti-war film]                                   0.4689      0.421      1.114      0.265      -0.356       1.294
# C(genres)[T.Apocalyptic and post-apocalyptic fiction]        1.7280      0.498      3.468      0.001       0.752       2.705
# C(genres)[T.Archaeology]                                     2.9157      1.092      2.670      0.008       0.775       5.056
# C(genres)[T.Archives and records]                            2.2571      0.791      2.854      0.004       0.707       3.807
# C(genres)[T.Art film]                                       -0.8507      0.375     -2.266      0.023      -1.587      -0.115
# C(genres)[T.Auto racing]                                     0.6850      0.442      1.550      0.121      -0.181       1.551
# C(genres)[T.Avant-garde]                                    -1.9994      0.351     -5.704      0.000      -2.686      -1.312
# C(genres)[T.B-Western]                                      -1.2029      1.326     -0.907      0.364      -3.801       1.395
# C(genres)[T.B-movie]                                        -0.9089      0.359     -2.529      0.011      -1.613      -0.205
# C(genres)[T.Backstage Musical]                              -0.1741      0.738     -0.236      0.814      -1.621       1.273
# C(genres)[T.Baseball]                                        1.5839      0.859      1.843      0.065      -0.101       3.268
# C(genres)[T.Beach Film]                                     -0.2983      1.859     -0.160      0.873      -3.941       3.345
# C(genres)[T.Biker Film]                                      1.3592      0.738      1.842      0.066      -0.087       2.806
# C(genres)[T.Biographical film]                              -0.2918      0.261     -1.117      0.264      -0.804       0.220
# C(genres)[T.Biography]                                      -0.5045      0.259     -1.944      0.052      -1.013       0.004
# C(genres)[T.Biopic [feature]]                               -0.4250      0.272     -1.565      0.118      -0.957       0.107
# C(genres)[T.Black comedy]                                   -0.8425      0.258     -3.265      0.001      -1.348      -0.337
# C(genres)[T.Black-and-white]                                -0.6352      0.263     -2.414      0.016      -1.151      -0.120
# C(genres)[T.Blaxploitation]                                 -0.7633      0.551     -1.384      0.166      -1.844       0.317
# C(genres)[T.Bloopers & Candid Camera]                        0.3122      1.092      0.286      0.775      -1.827       2.452
# C(genres)[T.Bollywood]                                      -1.5287      0.674     -2.269      0.023      -2.849      -0.208
# C(genres)[T.Boxing]                                          0.3945      0.407      0.969      0.332      -0.403       1.192
# C(genres)[T.Breakdance]                                      0.7901      1.859      0.425      0.671      -2.853       4.433
# C(genres)[T.British Empire Film]                             0.3686      0.607      0.607      0.544      -0.822       1.559
# C(genres)[T.British New Wave]                               -0.4035      1.092     -0.370      0.712      -2.543       1.736
# C(genres)[T.Buddy cop]                                       2.5574      0.696      3.676      0.000       1.194       3.921
# C(genres)[T.Buddy film]                                      0.6977      0.268      2.607      0.009       0.173       1.222
# C(genres)[T.Business]                                       -1.5041      0.953     -1.578      0.115      -3.372       0.364
# C(genres)[T.Camp]                                            0.1816      1.326      0.137      0.891      -2.416       2.780
# C(genres)[T.Caper story]                                     0.0454      0.383      0.119      0.906      -0.705       0.796
# C(genres)[T.Cavalry Film]                                   -0.2996      1.326     -0.226      0.821      -2.898       2.299
# C(genres)[T.Chase Movie]                                     0.9721      0.330      2.947      0.003       0.326       1.619
# C(genres)[T.Childhood Drama]                                -0.4179      0.347     -1.205      0.228      -1.098       0.262
# C(genres)[T.Children's]                                      0.7178      0.274      2.616      0.009       0.180       1.256
# C(genres)[T.Children's Fantasy]                              0.8352      0.284      2.940      0.003       0.279       1.392
# C(genres)[T.Children's/Family]                               0.7866      0.261      3.015      0.003       0.275       1.298
# C(genres)[T.Chinese Movies]                                  0.2264      0.281      0.807      0.420      -0.324       0.776
# C(genres)[T.Christian film]                                 -0.5309      0.359     -1.479      0.139      -1.235       0.173
# C(genres)[T.Christmas movie]                                 1.2038      0.389      3.095      0.002       0.441       1.966
# C(genres)[T.Clay animation]                                 -1.7861      1.327     -1.346      0.178      -4.386       0.814
# C(genres)[T.Cold War]                                        0.5725      0.859      0.666      0.505      -1.112       2.257
# C(genres)[T.Combat Films]                                    0.2821      0.375      0.752      0.452      -0.453       1.017
# C(genres)[T.Comdedy]                                        -1.9477      1.861     -1.047      0.295      -5.595       1.699
# C(genres)[T.Comedy]                                         -0.0703      0.246     -0.286      0.775      -0.552       0.412
# C(genres)[T.Comedy Thriller]                                -0.7502      0.380     -1.973      0.048      -1.495      -0.005
# C(genres)[T.Comedy Western]                                  0.7789      0.521      1.494      0.135      -0.243       1.801
# C(genres)[T.Comedy film]                                    -0.8245      0.291     -2.833      0.005      -1.395      -0.254
# C(genres)[T.Comedy horror]                                   0.7758      0.953      0.814      0.416      -1.092       2.644
# C(genres)[T.Comedy of Errors]                               -0.0961      0.308     -0.313      0.755      -0.699       0.507
# C(genres)[T.Comedy of manners]                               0.0738      0.289      0.255      0.798      -0.493       0.640
# C(genres)[T.Comedy-drama]                                   -0.5351      0.254     -2.108      0.035      -1.033      -0.038
# C(genres)[T.Coming of age]                                  -0.3530      0.259     -1.362      0.173      -0.861       0.155
# C(genres)[T.Coming-of-age film]                              3.2771      1.859      1.763      0.078      -0.366       6.920
# C(genres)[T.Computer Animation]                              1.4990      0.300      4.991      0.000       0.910       2.088
# C(genres)[T.Concert film]                                    0.6126      0.661      0.927      0.354      -0.683       1.908
# C(genres)[T.Costume Adventure]                               0.6689      0.363      1.842      0.065      -0.043       1.381
# C(genres)[T.Costume Horror]                                  1.0374      0.498      2.081      0.037       0.060       2.014
# C(genres)[T.Costume drama]                                   0.4965      0.263      1.891      0.059      -0.018       1.011
# C(genres)[T.Courtroom Comedy]                                0.5547      0.859      0.645      0.519      -1.130       2.239
# C(genres)[T.Courtroom Drama]                                 0.3025      0.300      1.009      0.313      -0.285       0.890
# C(genres)[T.Creature Film]                                   0.3731      0.300      1.242      0.214      -0.216       0.962
# C(genres)[T.Crime]                                          -1.8091      0.953     -1.898      0.058      -3.677       0.059
# C(genres)[T.Crime Comedy]                                   -0.3354      0.303     -1.108      0.268      -0.929       0.258
# C(genres)[T.Crime Drama]                                    -0.5585      0.291     -1.920      0.055      -1.129       0.012
# C(genres)[T.Crime Fiction]                                  -0.0026      0.248     -0.011      0.992      -0.489       0.484
# C(genres)[T.Crime Thriller]                                 -0.0003      0.253     -0.001      0.999      -0.496       0.495
# C(genres)[T.Cult]                                           -0.0451      0.261     -0.172      0.863      -0.558       0.467
# C(genres)[T.Culture & Society]                              -1.8044      0.375     -4.806      0.000      -2.540      -1.068
# C(genres)[T.Cyberpunk]                                       0.8112      0.860      0.944      0.345      -0.873       2.496
# C(genres)[T.Dance]                                           0.6462      0.396      1.632      0.103      -0.130       1.422
# C(genres)[T.Demonic child]                                   1.8154      0.738      2.460      0.014       0.369       3.262
# C(genres)[T.Detective]                                       0.0476      0.308      0.154      0.877      -0.557       0.652
# C(genres)[T.Detective fiction]                               0.1875      0.320      0.587      0.557      -0.439       0.814
# C(genres)[T.Disaster]                                        0.6495      0.303      2.145      0.032       0.056       1.243
# C(genres)[T.Docudrama]                                      -0.3015      0.297     -1.014      0.310      -0.884       0.281
# C(genres)[T.Documentary]                                    -1.3800      0.299     -4.608      0.000      -1.967      -0.793
# C(genres)[T.Dogme 95]                                       -2.7046      1.091     -2.478      0.013      -4.844      -0.566
# C(genres)[T.Domestic Comedy]                                 0.2917      0.292      0.999      0.318      -0.280       0.864
# C(genres)[T.Doomsday film]                                   1.3305      0.299      4.450      0.000       0.744       1.916
# C(genres)[T.Drama]                                          -0.3080      0.245     -1.255      0.209      -0.789       0.173
# C(genres)[T.Dystopia]                                        0.6833      0.347      1.971      0.049       0.004       1.363
# C(genres)[T.Educational]                                     3.3320      1.325      2.514      0.012       0.734       5.930
# C(genres)[T.Ensemble Film]                                  -0.6896      0.272     -2.533      0.011      -1.223      -0.156
# C(genres)[T.Environmental Science]                           0.2935      1.092      0.269      0.788      -1.846       2.433
# C(genres)[T.Epic]                                            0.5094      0.282      1.804      0.071      -0.044       1.063
# C(genres)[T.Epic Western]                                    1.0999      0.550      2.000      0.046       0.022       2.178
# C(genres)[T.Erotic Drama]                                   -0.4617      0.343     -1.347      0.178      -1.134       0.210
# C(genres)[T.Erotic thriller]                                 0.0794      0.311      0.255      0.799      -0.531       0.690
# C(genres)[T.Erotica]                                        -0.0983      0.324     -0.303      0.762      -0.734       0.537
# C(genres)[T.Escape Film]                                     0.1816      0.416      0.437      0.662      -0.634       0.997
# C(genres)[T.Essay Film]                                     -0.3643      0.954     -0.382      0.703      -2.235       1.506
# C(genres)[T.Existentialism]                                  0.3777      0.411      0.918      0.358      -0.428       1.184
# C(genres)[T.Experimental film]                              -2.0168      0.347     -5.808      0.000      -2.697      -1.336
# C(genres)[T.Extreme Sports]                                  0.4980      0.953      0.522      0.601      -1.370       2.366
# C(genres)[T.Fairy tale]                                      0.8046      0.455      1.767      0.077      -0.088       1.697
# C(genres)[T.Family Drama]                                   -0.4323      0.263     -1.644      0.100      -0.948       0.083
# C(genres)[T.Family Film]                                     0.7607      0.250      3.041      0.002       0.270       1.251
# C(genres)[T.Family-Oriented Adventure]                       0.8087      0.285      2.833      0.005       0.249       1.368
# C(genres)[T.Fantasy]                                         0.6391      0.251      2.550      0.011       0.148       1.130
# C(genres)[T.Fantasy Adventure]                               0.9201      0.281      3.278      0.001       0.370       1.470
# C(genres)[T.Fantasy Comedy]                                  0.8269      0.289      2.864      0.004       0.261       1.393
# C(genres)[T.Fantasy Drama]                                  -0.6495      0.522     -1.245      0.213      -1.672       0.373
# C(genres)[T.Feature film]                                   -4.4898      1.328     -3.381      0.001      -7.092      -1.887
# C(genres)[T.Female buddy film]                               1.8407      0.953      1.931      0.053      -0.027       3.709
# C(genres)[T.Feminist Film]                                  -0.1097      0.344     -0.319      0.750      -0.784       0.565
# C(genres)[T.Fictional film]                                 -2.9176      1.859     -1.570      0.116      -6.560       0.725
# C(genres)[T.Filipino Movies]                                -0.0434      1.003     -0.043      0.965      -2.009       1.923
# C(genres)[T.Film]                                           -2.3615      0.586     -4.031      0.000      -3.510      -1.213
# C(genres)[T.Film & Television History]                      -3.2433      0.953     -3.403      0.001      -5.112      -1.375
# C(genres)[T.Film adaptation]                                 0.0097      0.252      0.039      0.969      -0.484       0.503
# C(genres)[T.Film noir]                                      -0.6250      0.315     -1.987      0.047      -1.242      -0.008
# C(genres)[T.Film à clef]                                    -1.3199      0.521     -2.532      0.011      -2.342      -0.298
# C(genres)[T.Filmed Play]                                    -0.7395      1.859     -0.398      0.691      -4.382       2.903
# C(genres)[T.Finance & Investing]                            -2.7819      1.326     -2.099      0.036      -5.380      -0.184
# C(genres)[T.Future noir]                                     0.3341      0.436      0.766      0.444      -0.521       1.189
# C(genres)[T.Gangster Film]                                  -0.2701      0.280     -0.963      0.335      -0.820       0.279
# C(genres)[T.Gay]                                            -2.2487      0.296     -7.588      0.000      -2.830      -1.668
# C(genres)[T.Gay Interest]                                   -2.2287      0.297     -7.511      0.000      -2.810      -1.647
# C(genres)[T.Gay Themed]                                     -2.2243      0.292     -7.625      0.000      -2.796      -1.653
# C(genres)[T.Gay pornography]                                -5.0249      1.326     -3.790      0.000      -7.623      -2.426
# C(genres)[T.Gender Issues]                                  -2.0920      0.738     -2.833      0.005      -3.539      -0.645
# C(genres)[T.Glamorized Spy Film]                             2.2286      0.359      6.203      0.000       1.524       2.933
# C(genres)[T.Goat gland]                                      0.6742      1.859      0.363      0.717      -2.969       4.318
# C(genres)[T.Gothic Film]                                     1.3529      0.412      3.288      0.001       0.546       2.159
# C(genres)[T.Graphic & Applied Arts]                         -0.1423      0.953     -0.149      0.881      -2.011       1.726
# C(genres)[T.Gross out]                                       0.2638      0.342      0.771      0.441      -0.407       0.935
# C(genres)[T.Gross-out film]                                  0.2638      0.342      0.771      0.441      -0.407       0.935
# C(genres)[T.Gulf War]                                        1.4224      0.859      1.655      0.098      -0.262       3.107
# C(genres)[T.Hagiography]                                    -0.6903      0.566     -1.219      0.223      -1.800       0.420
# C(genres)[T.Hardcore pornography]                            2.1456      1.326      1.619      0.106      -0.453       4.744
# C(genres)[T.Haunted House Film]                              0.5011      0.420      1.192      0.233      -0.323       1.325
# C(genres)[T.Heaven-Can-Wait Fantasies]                       0.0296      0.550      0.054      0.957      -1.048       1.107
# C(genres)[T.Heavenly Comedy]                                 0.3212      0.566      0.567      0.571      -0.789       1.431
# C(genres)[T.Heist]                                          -0.0230      0.321     -0.071      0.943      -0.653       0.607
# C(genres)[T.Hip hop movies]                                  0.1457      0.538      0.271      0.786      -0.908       1.199
# C(genres)[T.Historical Documentaries]                        4.1597      1.859      2.238      0.025       0.516       7.803
# C(genres)[T.Historical Epic]                                 0.8028      0.378      2.122      0.034       0.061       1.544
# C(genres)[T.Historical drama]                                0.3598      0.375      0.960      0.337      -0.375       1.095
# C(genres)[T.Historical fiction]                              0.0738      0.301      0.245      0.806      -0.516       0.664
# C(genres)[T.History]                                         0.1750      0.274      0.639      0.523      -0.361       0.711
# C(genres)[T.Holiday Film]                                    0.5648      0.403      1.401      0.161      -0.225       1.355
# C(genres)[T.Horror]                                          0.2102      0.251      0.839      0.402      -0.281       0.701
# C(genres)[T.Horror Comedy]                                   0.0312      0.325      0.096      0.924      -0.605       0.668
# C(genres)[T.Horse racing]                                    0.5382      1.325      0.406      0.685      -2.060       3.136
# C(genres)[T.Humour]                                          1.4850      1.092      1.360      0.174      -0.656       3.626
# C(genres)[T.Hybrid Western]                                  0.2340      0.607      0.386      0.700      -0.956       1.424
# C(genres)[T.Indian Western]                                  0.4866      0.607      0.802      0.423      -0.703       1.676
# C(genres)[T.Indie]                                          -1.4304      0.249     -5.746      0.000      -1.918      -0.942
# C(genres)[T.Inspirational Drama]                            -0.1312      0.509     -0.258      0.797      -1.129       0.867
# C(genres)[T.Instrumental Music]                             -2.5411      1.092     -2.328      0.020      -4.681      -0.401
# C(genres)[T.Interpersonal Relationships]                    -2.4755      0.953     -2.597      0.009      -4.344      -0.607
# C(genres)[T.Inventions & Innovations]                       -1.3782      1.859     -0.742      0.458      -5.021       2.265
# C(genres)[T.Japanese Movies]                                 0.1597      0.263      0.607      0.544      -0.356       0.676
# C(genres)[T.Journalism]                                     -2.4405      0.739     -3.301      0.001      -3.890      -0.991
# C(genres)[T.Jukebox musical]                                -0.7431      0.607     -1.225      0.221      -1.933       0.446
# C(genres)[T.Jungle Film]                                     0.5555      0.443      1.255      0.209      -0.312       1.423
# C(genres)[T.Juvenile Delinquency Film]                      -0.2645      0.791     -0.334      0.738      -1.815       1.286
# C(genres)[T.Kafkaesque]                                     -0.1072      0.740     -0.145      0.885      -1.557       1.343
# C(genres)[T.Kitchen sink realism]                            1.4185      1.859      0.763      0.445      -2.225       5.062
# C(genres)[T.LGBT]                                           -1.1480      0.261     -4.391      0.000      -1.660      -0.636
# C(genres)[T.Law & Crime]                                    -2.9602      0.860     -3.444      0.001      -4.645      -1.275
# C(genres)[T.Legal drama]                                     1.7913      0.791      2.265      0.024       0.241       3.341
# C(genres)[T.Libraries and librarians]                       -0.2455      1.091     -0.225      0.822      -2.385       1.894
# C(genres)[T.Live action]                                     2.2853      1.092      2.094      0.036       0.146       4.425
# C(genres)[T.Marriage Drama]                                 -0.5454      0.334     -1.635      0.102      -1.199       0.108
# C(genres)[T.Martial Arts Film]                               0.7217      0.273      2.646      0.008       0.187       1.256
# C(genres)[T.Master Criminal Films]                           1.7208      0.521      3.301      0.001       0.699       2.743
# C(genres)[T.Media Satire]                                   -0.4011      0.372     -1.078      0.281      -1.131       0.328
# C(genres)[T.Media Studies]                                  -4.6171      0.953     -4.843      0.000      -6.486      -2.748
# C(genres)[T.Medical fiction]                                 0.3391      0.436      0.777      0.437      -0.516       1.194
# C(genres)[T.Melodrama]                                      -0.0125      0.288     -0.043      0.965      -0.578       0.553
# C(genres)[T.Mockumentary]                                   -1.2127      0.448     -2.705      0.007      -2.092      -0.334
# C(genres)[T.Monster]                                         1.0273      0.449      2.290      0.022       0.148       1.907
# C(genres)[T.Monster movie]                                   0.3387      0.368      0.922      0.357      -0.382       1.059
# C(genres)[T.Movies About Gladiators]                         2.0582      0.953      2.160      0.031       0.190       3.926
# C(genres)[T.Mumblecore]                                     -2.9667      0.953     -3.113      0.002      -4.835      -1.099
# C(genres)[T.Music]                                          -0.2536      0.280     -0.904      0.366      -0.803       0.296
# C(genres)[T.Musical]                                         0.0285      0.255      0.112      0.911      -0.471       0.528
# C(genres)[T.Musical Drama]                                   0.3471      0.302      1.150      0.250      -0.244       0.939
# C(genres)[T.Musical comedy]                                 -0.3350      0.327     -1.025      0.305      -0.976       0.306
# C(genres)[T.Mystery]                                         0.2514      0.251      1.001      0.317      -0.241       0.744
# C(genres)[T.Mythological Fantasy]                            0.9939      0.738      1.347      0.178      -0.453       2.440
# C(genres)[T.Natural disaster]                                0.8387      0.738      1.136      0.256      -0.608       2.285
# C(genres)[T.Natural horror films]                            0.7373      0.363      2.031      0.042       0.026       1.449
# C(genres)[T.Nature]                                          0.9644      0.953      1.012      0.312      -0.904       2.833
# C(genres)[T.Neo-noir]                                       -0.5512      0.352     -1.567      0.117      -1.240       0.138
# C(genres)[T.New Hollywood]                                   1.4853      0.326      4.558      0.000       0.847       2.124
# C(genres)[T.News]                                           -4.2195      1.859     -2.270      0.023      -7.862      -0.577
# C(genres)[T.Ninja movie]                                     0.9021      1.326      0.681      0.496      -1.696       3.500
# C(genres)[T.Northern]                                       -0.3590      1.092     -0.329      0.742      -2.499       1.780
# C(genres)[T.Outlaw]                                          1.5301      0.859      1.780      0.075      -0.154       3.215
# C(genres)[T.Outlaw biker film]                               0.0474      0.859      0.055      0.956      -1.637       1.732
# C(genres)[T.Parkour in popular culture]                      0.9725      0.701      1.388      0.165      -0.401       2.346
# C(genres)[T.Parody]                                         -0.3690      0.261     -1.416      0.157      -0.880       0.142
# C(genres)[T.Period Horror]                                   1.5412      1.326      1.163      0.245      -1.057       4.139
# C(genres)[T.Period piece]                                   -0.3199      0.250     -1.278      0.201      -0.810       0.171
# C(genres)[T.Plague]                                          1.8685      0.535      3.492      0.000       0.820       2.917
# C(genres)[T.Point of view shot]                              3.9222      1.859      2.110      0.035       0.279       7.565
# C(genres)[T.Political cinema]                               -1.0085      0.313     -3.226      0.001      -1.621      -0.396
# C(genres)[T.Political drama]                                -0.5724      0.267     -2.144      0.032      -1.096      -0.049
# C(genres)[T.Political satire]                               -0.7223      0.354     -2.043      0.041      -1.415      -0.029
# C(genres)[T.Political thriller]                              0.0829      0.294      0.282      0.778      -0.492       0.658
# C(genres)[T.Pornographic movie]                              0.5145      0.661      0.778      0.436      -0.781       1.810
# C(genres)[T.Pre-Code]                                       -0.6683      0.439     -1.523      0.128      -1.528       0.191
# C(genres)[T.Prison]                                         -0.4089      0.383     -1.067      0.286      -1.160       0.342
# C(genres)[T.Prison film]                                     0.5484      0.792      0.693      0.489      -1.004       2.101
# C(genres)[T.Private military company]                        2.2163      1.326      1.672      0.095      -0.382       4.814
# C(genres)[T.Propaganda film]                                 0.5999      0.953      0.629      0.529      -1.269       2.469
# C(genres)[T.Psycho-biddy]                                    0.1989      1.092      0.182      0.855      -1.941       2.338
# C(genres)[T.Psychological horror]                           -3.5397      1.859     -1.905      0.057      -7.182       0.103
# C(genres)[T.Psychological thriller]                          0.1882      0.256      0.734      0.463      -0.314       0.691
# C(genres)[T.Punk rock]                                      -2.5221      0.953     -2.646      0.008      -4.390      -0.654
# C(genres)[T.Reboot]                                          2.1600      0.537      4.024      0.000       1.108       3.212
# C(genres)[T.Religious Film]                                  0.1722      0.470      0.366      0.714      -0.750       1.094
# C(genres)[T.Remake]                                          1.3863      0.313      4.425      0.000       0.772       2.000
# C(genres)[T.Revisionist Fairy Tale]                          2.4438      1.325      1.844      0.065      -0.154       5.042
# C(genres)[T.Revisionist Western]                             0.1381      0.420      0.328      0.743      -0.686       0.962
# C(genres)[T.Road movie]                                     -0.5043      0.287     -1.760      0.078      -1.066       0.057
# C(genres)[T.Road-Horror]                                     0.5544      0.550      1.009      0.313      -0.523       1.632
# C(genres)[T.Roadshow theatrical release]                     1.2470      0.383      3.253      0.001       0.496       1.998
# C(genres)[T.Rockumentary]                                    0.0362      0.859      0.042      0.966      -1.648       1.721
# C(genres)[T.Romance Film]                                   -0.0837      0.247     -0.339      0.735      -0.567       0.400
# C(genres)[T.Romantic comedy]                                -0.0354      0.250     -0.141      0.888      -0.526       0.456
# C(genres)[T.Romantic drama]                                 -0.2516      0.250     -1.004      0.315      -0.742       0.239
# C(genres)[T.Romantic fantasy]                                0.6196      0.425      1.457      0.145      -0.214       1.453
# C(genres)[T.Samurai cinema]                                 -0.1118      0.954     -0.117      0.907      -1.981       1.758
# C(genres)[T.Satire]                                         -0.3126      0.271     -1.151      0.250      -0.845       0.219
# C(genres)[T.School story]                                    0.8369      0.859      0.974      0.330      -0.848       2.521
# C(genres)[T.Sci-Fi Adventure]                                1.9140      0.431      4.445      0.000       1.070       2.758
# C(genres)[T.Sci-Fi Horror]                                   1.3274      0.342      3.877      0.000       0.656       1.998
# C(genres)[T.Sci-Fi Thriller]                                 1.3935      1.325      1.051      0.293      -1.204       3.991
# C(genres)[T.Science Fiction]                                 0.6342      0.252      2.520      0.012       0.141       1.128
# C(genres)[T.Science fiction Western]                         1.1900      1.092      1.089      0.276      -0.951       3.331
# C(genres)[T.Screwball comedy]                                0.1528      0.285      0.537      0.591      -0.405       0.711
# C(genres)[T.Sex comedy]                                     -0.0759      0.290     -0.261      0.794      -0.645       0.493
# C(genres)[T.Sexploitation]                                   1.1008      0.567      1.943      0.052      -0.010       2.211
# C(genres)[T.Short Film]                                     -0.0405      0.389     -0.104      0.917      -0.803       0.722
# C(genres)[T.Silent film]                                     0.0069      0.409      0.017      0.987      -0.794       0.808
# C(genres)[T.Slapstick]                                       0.4859      0.270      1.796      0.072      -0.044       1.016
# C(genres)[T.Slasher]                                         0.1812      0.272      0.667      0.504      -0.351       0.713
# C(genres)[T.Slice of life story]                            -0.3941      0.359     -1.097      0.273      -1.098       0.310
# C(genres)[T.Social issues]                                  -1.7055      0.471     -3.621      0.000      -2.629      -0.782
# C(genres)[T.Social problem film]                            -0.5763      0.437     -1.319      0.187      -1.433       0.280
# C(genres)[T.Softcore Porn]                                  -0.6539      0.738     -0.886      0.376      -2.101       0.793
# C(genres)[T.Space opera]                                     1.9957      0.859      2.322      0.020       0.311       3.680
# C(genres)[T.Space western]                                   1.0101      0.791      1.277      0.201      -0.540       2.560
# C(genres)[T.Spaghetti Western]                               1.2552      0.739      1.699      0.089      -0.193       2.703
# C(genres)[T.Splatter film]                                   1.1275      0.661      1.706      0.088      -0.168       2.423
# C(genres)[T.Sports]                                          0.1389      0.263      0.529      0.597      -0.376       0.654
# C(genres)[T.Spy]                                             0.9709      0.284      3.418      0.001       0.414       1.528
# C(genres)[T.Stand-up comedy]                                 0.7879      0.738      1.068      0.286      -0.659       2.235
# C(genres)[T.Star vehicle]                                   -1.3367      1.859     -0.719      0.472      -4.980       2.306
# C(genres)[T.Steampunk]                                       1.0991      0.383      2.869      0.004       0.348       1.850
# C(genres)[T.Stoner film]                                    -0.4121      0.386     -1.068      0.286      -1.168       0.344
# C(genres)[T.Stop motion]                                     0.2500      0.347      0.721      0.471      -0.430       0.930
# C(genres)[T.Superhero]                                       1.1990      0.317      3.782      0.000       0.578       1.820
# C(genres)[T.Superhero movie]                                 1.1207      0.282      3.976      0.000       0.568       1.673
# C(genres)[T.Supermarionation]                               -0.0220      1.326     -0.017      0.987      -2.620       2.576
# C(genres)[T.Supernatural]                                    0.9025      0.269      3.354      0.001       0.375       1.430
# C(genres)[T.Surrealism]                                     -0.9934      0.383     -2.590      0.010      -1.745      -0.242
# C(genres)[T.Suspense]                                        0.4011      0.263      1.525      0.127      -0.114       0.917
# C(genres)[T.Swashbuckler films]                              0.3698      0.349      1.061      0.289      -0.313       1.053
# C(genres)[T.Sword and Sandal]                                0.8901      0.537      1.657      0.097      -0.163       1.943
# C(genres)[T.Sword and sorcery]                               0.7378      0.416      1.773      0.076      -0.078       1.553
# C(genres)[T.Sword and sorcery films]                         1.0258      0.389      2.634      0.008       0.262       1.789
# C(genres)[T.Tamil cinema]                                   -0.1337      1.100     -0.122      0.903      -2.290       2.022
# C(genres)[T.Teen]                                            0.0802      0.258      0.311      0.756      -0.426       0.586
# C(genres)[T.Television movie]                               -1.5401      0.510     -3.020      0.003      -2.540      -0.540
# C(genres)[T.The Netherlands in World War II]                 0.9133      1.326      0.689      0.491      -1.685       3.511
# C(genres)[T.Therimin music]                                 -0.6667      1.092     -0.611      0.541      -2.806       1.473
# C(genres)[T.Thriller]                                        0.4039      0.247      1.638      0.101      -0.079       0.887
# C(genres)[T.Time travel]                                     0.6885      0.337      2.044      0.041       0.028       1.349
# C(genres)[T.Tragedy]                                         1.0251      0.332      3.087      0.002       0.374       1.676
# C(genres)[T.Tragicomedy]                                    -0.2331      0.436     -0.534      0.593      -1.088       0.622
# C(genres)[T.Travel]                                         -0.2677      0.791     -0.338      0.735      -1.818       1.283
# C(genres)[T.Vampire movies]                                 -0.3273      1.091     -0.300      0.764      -2.467       1.812
# C(genres)[T.War film]                                       -0.0026      0.255     -0.010      0.992      -0.503       0.497
# C(genres)[T.Werewolf fiction]                                1.3547      0.738      1.834      0.067      -0.093       2.802
# C(genres)[T.Western]                                        -0.1963      0.267     -0.736      0.462      -0.719       0.326
# C(genres)[T.Whodunit]                                        0.7609      0.509      1.494      0.135      -0.238       1.759
# C(genres)[T.Women in prison films]                           0.6509      0.967      0.673      0.501      -1.245       2.546
# C(genres)[T.Workplace Comedy]                                0.0718      0.367      0.196      0.845      -0.648       0.792
# C(genres)[T.World History]                                  -2.7178      0.697     -3.897      0.000      -4.085      -1.351
# C(genres)[T.World cinema]                                   -0.5147      0.251     -2.048      0.041      -1.007      -0.022
# C(genres)[T.Wuxia]                                           1.4839      0.501      2.959      0.003       0.501       2.467
# C(genres)[T.Zombie Film]                                     0.4204      0.314      1.338      0.181      -0.195       1.036
# C(countries)[T.Argentina]                                   -1.3823      0.676     -2.045      0.041      -2.707      -0.058
# C(countries)[T.Australia]                                   -0.6459      0.655     -0.986      0.324      -1.930       0.638
# C(countries)[T.Austria]                                     -2.5472      0.683     -3.727      0.000      -3.887      -1.208
# C(countries)[T.Bahamas]                                      1.2766      0.928      1.376      0.169      -0.542       3.095
# C(countries)[T.Belgium]                                     -1.7104      0.666     -2.568      0.010      -3.016      -0.405
# C(countries)[T.Bosnia and Herzegovina]                      -3.7795      0.857     -4.411      0.000      -5.459      -2.100
# C(countries)[T.Brazil]                                      -0.8131      0.697     -1.166      0.244      -2.180       0.554
# C(countries)[T.Bulgaria]                                    -2.5912      0.767     -3.380      0.001      -4.094      -1.089
# C(countries)[T.Canada]                                      -1.4181      0.654     -2.169      0.030      -2.700      -0.136
# C(countries)[T.China]                                        0.0519      0.661      0.079      0.937      -1.243       1.347
# C(countries)[T.Colombia]                                    -0.2498      0.876     -0.285      0.775      -1.966       1.467
# C(countries)[T.Croatia]                                     -3.6130      0.954     -3.785      0.000      -5.484      -1.742
# C(countries)[T.Czech Republic]                              -0.4415      0.665     -0.664      0.507      -1.745       0.862
# C(countries)[T.Denmark]                                     -2.0468      0.673     -3.042      0.002      -3.365      -0.728
# C(countries)[T.Egypt]                                       -1.4204      1.052     -1.350      0.177      -3.483       0.642
# C(countries)[T.England]                                     -2.0782      0.674     -3.081      0.002      -3.400      -0.756
# C(countries)[T.Finland]                                     -1.2066      0.689     -1.752      0.080      -2.557       0.144
# C(countries)[T.France]                                      -1.1428      0.653     -1.749      0.080      -2.423       0.138
# C(countries)[T.Germany]                                     -0.7306      0.653     -1.118      0.263      -2.011       0.550
# C(countries)[T.Greece]                                      -1.0812      0.757     -1.429      0.153      -2.564       0.402
# C(countries)[T.Hong Kong]                                   -0.5160      0.657     -0.785      0.432      -1.804       0.772
# C(countries)[T.Hungary]                                     -1.7866      0.680     -2.626      0.009      -3.120      -0.453
# C(countries)[T.Iceland]                                     -1.9242      0.707     -2.722      0.006      -3.310      -0.539
# C(countries)[T.India]                                       -1.8429      0.667     -2.764      0.006      -3.150      -0.536
# C(countries)[T.Indonesia]                                   -2.5676      0.922     -2.784      0.005      -4.375      -0.760
# C(countries)[T.Iran]                                        -3.4597      0.737     -4.696      0.000      -4.904      -2.016
# C(countries)[T.Ireland]                                     -1.4191      0.659     -2.152      0.031      -2.711      -0.127
# C(countries)[T.Isle of Man]                                 -1.8825      1.051     -1.790      0.073      -3.943       0.178
# C(countries)[T.Israel]                                      -1.7105      0.678     -2.525      0.012      -3.038      -0.383
# C(countries)[T.Italy]                                       -1.0248      0.655     -1.564      0.118      -2.309       0.260
# C(countries)[T.Jamaica]                                     -1.0140      1.057     -0.960      0.337      -3.085       1.057
# C(countries)[T.Japan]                                       -0.9192      0.655     -1.404      0.160      -2.202       0.364
# C(countries)[T.Kenya]                                       -2.1459      1.249     -1.718      0.086      -4.595       0.303
# C(countries)[T.Kingdom of Great Britain]                    -2.6380      0.714     -3.692      0.000      -4.038      -1.238
# C(countries)[T.Korea]                                       -2.4641      0.737     -3.342      0.001      -3.909      -1.019
# C(countries)[T.Kuwait]                                      -0.8796      0.875     -1.006      0.315      -2.594       0.835
# C(countries)[T.Lebanon]                                     -0.3909      0.791     -0.494      0.621      -1.942       1.160
# C(countries)[T.Libya]                                       -0.6616      0.922     -0.718      0.473      -2.469       1.146
# C(countries)[T.Lithuania]                                   -0.9489      1.051     -0.903      0.367      -3.009       1.112
# C(countries)[T.Luxembourg]                                  -1.5524      0.674     -2.303      0.021      -2.874      -0.231
# C(countries)[T.Malaysia]                                    -1.8632      0.875     -2.129      0.033      -3.578      -0.148
# C(countries)[T.Malta]                                        1.4892      0.843      1.766      0.077      -0.164       3.142
# C(countries)[T.Mexico]                                      -1.3891      0.666     -2.086      0.037      -2.694      -0.084
# C(countries)[T.Mongolia]                                    -0.6063      0.897     -0.676      0.499      -2.364       1.152
# C(countries)[T.Morocco]                                     -0.6816      0.740     -0.922      0.357      -2.131       0.768
# C(countries)[T.Netherlands]                                 -1.7336      0.667     -2.601      0.009      -3.040      -0.427
# C(countries)[T.New Zealand]                                 -1.0108      0.658     -1.535      0.125      -2.301       0.280
# C(countries)[T.Nigeria]                                      1.9528      1.957      0.998      0.318      -1.882       5.788
# C(countries)[T.Norway]                                      -1.6713      0.697     -2.399      0.016      -3.037      -0.306
# C(countries)[T.Pakistan]                                    -2.7507      0.925     -2.972      0.003      -4.564      -0.937
# C(countries)[T.Panama]                                      -0.1466      0.897     -0.164      0.870      -1.904       1.611
# C(countries)[T.Peru]                                         2.0702      1.129      1.834      0.067      -0.142       4.283
# C(countries)[T.Philippines]                                 -0.3914      0.904     -0.433      0.665      -2.163       1.380
# C(countries)[T.Poland]                                      -1.6020      0.704     -2.277      0.023      -2.981      -0.223
# C(countries)[T.Portugal]                                    -2.5195      0.750     -3.361      0.001      -3.989      -1.050
# C(countries)[T.Puerto Rico]                                 -2.8009      0.897     -3.124      0.002      -4.558      -1.044
# C(countries)[T.Qatar]                                       -1.8997      1.459     -1.302      0.193      -4.759       0.960
# C(countries)[T.Romania]                                     -1.4544      0.697     -2.087      0.037      -2.820      -0.089
# C(countries)[T.Russia]                                      -1.1047      0.680     -1.624      0.104      -2.438       0.229
# C(countries)[T.Scotland]                                    -2.2783      0.740     -3.080      0.002      -3.728      -0.828
# C(countries)[T.Serbia]                                      -4.4020      0.753     -5.845      0.000      -5.878      -2.926
# C(countries)[T.Serbia and Montenegro]                       -4.3894      0.996     -4.408      0.000      -6.341      -2.438
# C(countries)[T.Singapore]                                   -1.7155      0.818     -2.098      0.036      -3.318      -0.113
# C(countries)[T.Slovak Republic]                             -2.2472      0.799     -2.811      0.005      -3.814      -0.680
# C(countries)[T.Slovakia]                                    -1.3568      0.728     -1.865      0.062      -2.783       0.069
# C(countries)[T.Socialist Federal Republic of Yugoslavia]    -1.7173      0.876     -1.960      0.050      -3.435    8.78e-05
# C(countries)[T.South Africa]                                -1.2193      0.676     -1.803      0.071      -2.545       0.106
# C(countries)[T.South Korea]                                 -1.1327      0.655     -1.728      0.084      -2.417       0.152
# C(countries)[T.Soviet Union]                                -2.4406      1.249     -1.954      0.051      -4.889       0.007
# C(countries)[T.Spain]                                       -0.9616      0.658     -1.462      0.144      -2.251       0.327
# C(countries)[T.Sweden]                                      -1.5593      0.671     -2.325      0.020      -2.874      -0.245
# C(countries)[T.Switzerland]                                 -1.0078      0.676     -1.491      0.136      -2.333       0.317
# C(countries)[T.Taiwan]                                      -0.1449      0.697     -0.208      0.835      -1.511       1.221
# C(countries)[T.Thailand]                                    -1.1325      0.720     -1.574      0.116      -2.543       0.278
# C(countries)[T.Tunisia]                                     -1.2572      0.773     -1.627      0.104      -2.771       0.257
# C(countries)[T.Turkey]                                      -1.3942      0.711     -1.961      0.050      -2.787      -0.001
# C(countries)[T.Ukraine]                                      0.4666      1.248      0.374      0.709      -1.980       2.913
# C(countries)[T.United Arab Emirates]                        -0.4879      0.707     -0.690      0.490      -1.874       0.898
# C(countries)[T.United Kingdom]                              -1.0047      0.653     -1.539      0.124      -2.284       0.275
# C(countries)[T.United States of America]                    -0.7935      0.652     -1.216      0.224      -2.072       0.485
# C(countries)[T.Uruguay]                                     -0.5021      0.922     -0.545      0.586      -2.309       1.305
# C(countries)[T.Vietnam]                                     -1.5053      1.051     -1.432      0.152      -3.566       0.556
# C(countries)[T.Weimar Republic]                             -4.8424      1.133     -4.275      0.000      -7.063      -2.622
# C(countries)[T.West Germany]                                -0.9918      0.676     -1.467      0.142      -2.317       0.333
# C(countries)[T.Yugoslavia]                                  -2.7390      0.718     -3.816      0.000      -4.146      -1.332
# C(countries)[T.Zimbabwe]                                    -0.9189      0.858     -1.071      0.284      -2.600       0.762
# women_ratio                                                 -0.4253      0.049     -8.709      0.000      -0.521      -0.330
# movie_release_year                                           2.0168      0.062     32.598      0.000       1.896       2.138
# number_actors                                                9.8667      0.114     86.765      0.000       9.644      10.090
# ==============================================================================
# Omnibus:                     7133.531   Durbin-Watson:                   0.387
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11061.452
# Skew:                          -0.888   Prob(JB):                         0.00
# Kurtosis:                       4.198   Cond. No.                     1.21e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(res.params.women_ratio)
# Out:
# -0.4253029843871016

# %%
print(res.pvalues.sort_values()[:5])
# Out:
# number_actors               0.000000e+00
# movie_release_year         5.628735e-231
# Intercept                   7.030133e-93
# women_ratio                 3.131965e-18
# C(genres)[T.Gay Themed]     2.468621e-14
# dtype: float64

# %% [markdown]
# ##### After isolating the different factors, we can see that the `women_ratio` has a p_valued $<< \alpha$ so it does indeed negatively influence (negative coefficient) the office revenue of the movies.

# %% [markdown]
# Auxiliary function to make a subset from a column where values are dictionaries

# %%
def make_subset_gender_parity(col_name, gender_parity_df = gender_parity) :
    subset = gender_parity_df[['women_ratio','wikipedia_movie_id', col_name]].copy()

    #change the dict to list of values and explode them to get one value per row
    subset = deconstruct_dict(subset, col_name)

    #group by the desired column and make the mean of the women ratios
    subset = subset.groupby(col_name)\
        .agg({'women_ratio' : ['mean', bootstrap_ci], 'wikipedia_movie_id' : 'count'})\
        .sort_values(by=[('women_ratio', 'mean')])

    subset.columns = ['_'.join(col) for col in subset.columns.values]

    return subset.reset_index()

# %% [markdown]
# Plot the movie_gender per country on a world heat map.

# %%
#make the subset by country
movie_gender_country = make_subset_gender_parity('countries')

# %%
#get the world countries
countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# initialize an axis
fig, ax = plt.subplots(figsize=(8,6))
plt.title("World heatmap of the women ratio by country")

#plot the countries in light gray
countries.plot(color="k", alpha=0.1, ax=ax)

#add the color in function of the women ratio
df = countries.merge(movie_gender_country.loc[movie_gender_country['wikipedia_movie_id_count'] > 2]
                     .rename(columns={'countries' : 'name'}), on='name', how='inner')

continent = df[['continent', 'women_ratio_mean']].groupby('continent').mean().reset_index().rename(columns={'women_ratio_mean' : 'continent_women_ratio'})
df = countries.merge(continent,on='continent')


gpd.GeoDataFrame(df).plot(column='continent_women_ratio',ax=ax, legend=True) ;

# %% [markdown]
# Plot the women ratio by movie genres

# %%
genres = {"Action" : {"war", "military", "action", "spy", "espionage", "combat", "martial", "prison", "anti-war", "escape", "gangster", "escape", "heist", "epic"},
          "Comedy" : {"comedy", "fun", "parody"},
          "Horror" : {"horreur", "scary", "zombie"}, 
          "Science fiction" : {"space", "time", "science", "robot", "disaster", "apocalypse", "alien", "monster", "sci-fi", "fiction"},
          "Western" : {"western", "cowboy", "anti-western"},
          "Romance" : {"romance"},
          "Documentary" : {"society", "culture", "sport", "empire", "documentary", "sports"},
          "Thriller" : {"thriller", "spy", "conspiracy"},
          "Fantasy" : {"bangsian", "fantasy", "dark", "fables", "magic", "myth", "legends", "sorcery"},
          "Historical" : {"historical", "period", "history", "counterfactual"},
          "Crime" : {"detective", "crime", "murder", "mysteries", "enquete", "thief"},
          "Drama" : {"docudrama", "drama", "teen", "political", "melodrama", "issues"},
          "Animation" : {"animation", "motion", "stop", "claymation", "animated", "puppetry"},
          "Pornographic" : {"sex", "pornographic", "sexploitation", "erotica", "adult"}}

def regroup_genre(elements):
    for k,v in genres.items() :
        if len(elements.intersection(v)) :
            return k
    return pd.NaT

# %%
plot_ages = character_metadata.dropna()
plot_ages['year'] = pd.DatetimeIndex(plot_ages['movie_release_date']).year.astype('int')
plot_ages = plot_ages[['actor_gender','actor_age', 'year']]
plot_ages
# Out:
# /tmp/ipykernel_53391/2184746527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_ages['year'] = pd.DatetimeIndex(plot_ages['movie_release_date']).year.astype('int')
#        actor_gender  actor_age  year
# 1                 F       27.0  2001
# 2                 M       32.0  2001
# 5                 F       52.0  2001
# 56                M       34.0  2006
# 76                F       24.0  1999
# ...             ...        ...   ...
# 450565            F       25.0  1931
# 450585            M       58.0  2010
# 450586            M       27.0  2010
# 450587            F       27.0  2010
# 450631            F       30.0  1998
#
# [45264 rows x 3 columns]

# %%
plot_ages = plot_ages.groupby(['year', 'actor_gender']).mean()
plot_ages = plot_ages.reset_index()

plot_ages_men = plot_ages.loc[plot_ages['actor_gender'] == 'M'].sort_values(by='year').rename(columns={'actor_age' : 'men age'})
plot_ages_women = plot_ages.loc[plot_ages['actor_gender'] == 'F'].sort_values(by='year').rename(columns={'actor_age' : 'women age'})

ax = plot_ages_men.plot(x='year', y='men age', title="Mean age of actors")
plot_ages_women.plot.line(x='year', y='women age', ax=ax)
# Out:
# <AxesSubplot:title={'center':'Mean age of actors'}, xlabel='year'>

# %% [markdown]
# ## A. what is the gender parity across movie genres (are westerns still as male dominated as the stereotype describes it?)

# %%
def plot_ratio_by_categories(subset, col_name, min_count=100):
    filtered_subset = subset[subset.wikipedia_movie_id_count > min_count]

    plt.figure(figsize=(6, len(filtered_subset) * 0.2))
    for i, col in enumerate(filtered_subset[['women_ratio_mean', 'women_ratio_bootstrap_ci']].iloc):
        plt.plot(col['women_ratio_bootstrap_ci'], (i,i),'-|k')
        plt.plot(col['women_ratio_mean'], i, '.r')

    plt.yticks(range(len(filtered_subset)),list(filtered_subset[col_name]))

# %%
def split_gender_parity(treshold_year):
    before = gender_parity[gender_parity.movie_release_year <= treshold_year]
    after  = gender_parity[gender_parity.movie_release_year >  treshold_year]
    return before, after

# %%
def plot_evolution(col_name, treshold_year, min_count=100):
    gender_parity_before, gender_parity_after = split_gender_parity(treshold_year)

    before = make_subset_gender_parity(col_name, gender_parity_before)
    after  = make_subset_gender_parity(col_name, gender_parity_after )

    merged = before.merge(after, on=col_name, suffixes=('_before', '_after'))

    merged_filtered = merged[merged.wikipedia_movie_id_count_after + merged.wikipedia_movie_id_count_before > min_count]

    plt.figure(figsize=(6, len(merged_filtered) * 0.2))

    for y, col in enumerate(merged_filtered.iloc):
            ratio_before = col['women_ratio_mean_before']
            ratio_after  = col['women_ratio_mean_after' ]
            dx = ratio_after - ratio_before
            plt.plot(col['women_ratio_mean_before'], y, '.r')
            plt.arrow(ratio_before, y, dx, 0,
                      head_width = 0.7,
                      head_length = 0.005,
                      ec ='black')
    plt.yticks(range(len(merged_filtered)),list(merged_filtered[col_name]))

# %%
movie_gender_genre = make_subset_gender_parity('genres')
plot_ratio_by_categories(movie_gender_genre, 'genres')
plot_evolution('genres', 2000)

# %%
movie_gender_genre
# Out:
#                        genres  women_ratio_mean women_ratio_bootstrap_ci  \
# 0                      Travel          0.000000                      NaN
# 1                Anthropology          0.000000                      NaN
# 2               World History          0.000000                      NaN
# 3              Extreme Sports          0.018519                      NaN
# 4    Bloopers & Candid Camera          0.027778                      NaN
# ..                        ...               ...                      ...
# 305                Mumblecore          0.530220                      NaN
# 306  Libraries and librarians          0.557071                      NaN
# 307     Women in prison films          0.687500                      NaN
# 308      Kitchen sink realism          0.700000                      NaN
# 309  Historical Documentaries          1.000000                      NaN
#
#      wikipedia_movie_id_count
# 0                           5
# 1                           2
# 2                           2
# 3                           3
# 4                           2
# ..                        ...
# 305                         4
# 306                         3
# 307                         2
# 308                         1
# 309                         1
#
# [310 rows x 4 columns]

# %% [markdown]
# ## B. what is the evolution of gender parity in films among countries over time (were some countries avant-garde? Are some still behind on this concept?)

# %%
movie_gender_genre = make_subset_gender_parity('countries')
plot_ratio_by_categories(movie_gender_genre, 'countries', min_count=20)
plot_evolution('countries', 2000, min_count=20)

# %% [markdown]
# `countries_metadata.csv` key points :
# - `hdi_year` : human developement index of the contry by year
# - `gii_year` : gender inequality index

# %%
# source : https://hdr.undp.org/data-center/documentation-and-downloads
countries_metadata = pd.read_csv(DATA_FOLDER + 'countries_metadata.csv')

# %%
translate_countries = {
    'United States of America' : 'United States',
    'Hong Kong'                : 'Hong Kong, China (SAR)',
    'South Korea'              : 'Korea (Republic of)',
    'Korea'                    : 'Korea (Republic of)',
    'Russia' : 'Russian Federation',
    'England' : 'United Kingdom',
    'Scotland' : 'United Kingdom',
    'Kingdom of Great Britain' : 'United Kingdom',
    'Czech Republic':'Czechia',
    'Iran' : 'Iran (Islamic Republic of)',
    'Vietnam' : 'Viet Nam',
    'Slovak Republic' : 'Slovakia'
}

# %%
def find_index(country, year, index_name = 'hdi'):
    country = translate_countries.get(country, country)
    if year in range(1990, 2022) and country in list(countries_metadata.country):
        col = index_name + '_' + str(int(year))
        index =  countries_metadata[countries_metadata.country == country][col].iloc[0]
        return index
    return np.nan

# %%
parity_by_hdi = gender_parity[['wikipedia_movie_id','women_ratio', 'movie_release_year', 'countries']].copy()
parity_by_hdi = deconstruct_dict(parity_by_hdi, 'countries').dropna()
parity_by_hdi['country_year'] = list(zip(parity_by_hdi.countries, parity_by_hdi.movie_release_year))
parity_by_hdi['hdi'] = parity_by_hdi['country_year'].apply(lambda x : find_index(x[0], x[1], index_name = 'hdi'))
parity_by_hdi = parity_by_hdi.dropna()

# %%
parity_by_hdi
# Out:
#        wikipedia_movie_id  women_ratio  movie_release_year  \
# 0                    3217     0.230769              1992.0
# 8                    4231     0.375000              1992.0
# 9                    4560     0.133333              1995.0
# 12                   4728     0.363636              1992.0
# 13                   4728     0.363636              1992.0
# ...                   ...          ...                 ...
# 10845            36291706     1.000000              1994.0
# 10846            36329343     0.666667              2012.0
# 10855            36956792     0.185185              2007.0
# 10856            36956792     0.185185              2007.0
# 10857            36956792     0.185185              2007.0
#
#                       countries                        country_year    hdi
# 0      United States of America  (United States of America, 1992.0)  0.878
# 8      United States of America  (United States of America, 1992.0)  0.878
# 9      United States of America  (United States of America, 1995.0)  0.885
# 12     United States of America  (United States of America, 1992.0)  0.878
# 13               United Kingdom            (United Kingdom, 1992.0)  0.816
# ...                         ...                                 ...    ...
# 10845  United States of America  (United States of America, 1994.0)  0.884
# 10846  United States of America  (United States of America, 2012.0)  0.916
# 10855  United States of America  (United States of America, 2007.0)  0.906
# 10856               New Zealand               (New Zealand, 2007.0)  0.916
# 10857            United Kingdom            (United Kingdom, 2007.0)  0.897
#
# [7631 rows x 6 columns]

# %%
# plot_ratio_by_categories(movie_gender_country, 'countries', min_count=15, y_size=7)

# %% [markdown]
# # Step 3

# %% [markdown]
# We need to analyze the plot summaries, we can use the coreNLP data given. This is a function to give a Element Tree on the coreNLP parsed plot of a given wikipedia movie id.

# %% [markdown]
# # Milestone 2
#
# Keep the code to reuse

# %% [markdown]
# # 2. Freebase database
# Many features in our datasets have as format freebase ids. It is essential to be able to translate these features to their respective labels to properly understand our datasets and make precise analysis. This is why we made an auxiliary function to make queries to the freebase database.

# %% [markdown]
# ### 2.1 Defining functions
# We first define the `translate_freebase_list` function that returns a dict of freebase ID and its translations. Then define the `translate_freebase_df` function that we translate id for a full column on a dataframe.

# %%
def translate_freebase_list(freebase_ids) -> dict:
    """
    Uses queries to the wikidata database

    :param freebase_ids: list of string
    :return: dictionnary with id and it's translation
    """

    st = "\" \"".join(freebase_ids)
    st = "\"" + st + "\""

    query_content = """
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX wikibase: <http://wikiba.se/ontology#>

    SELECT DISTINCT ?ISNI ?idLabel WHERE {
    VALUES ?ISNI {%s}
    # ?id wdt:P646 ?ISNI
    SERVICE wikibase:label {
        bd:serviceParam wikibase:language "en" .
    }
    }
    """ % st

    query = "https://query.wikidata.org/bigdata/namespace/wdq/sparql?format=json&query=" + urllib.parse.quote_plus(query_content)
    response = requests.get(query)
    if not response.ok :
        print("Error in request")
        return np.NaN

    values = response.json()
    if len(values) == 0 :
        return np.NaN

    return dict([(item['ISNI']['value'], item['idLabel']['value']) for item in values['results']['bindings']])

# %% [markdown]
# Definition of the `translate_freebase_df` function.

# %%
#split a list into n pieces
def split(a, n):
    k, m = divmod(len(a), n)
    return (a[i*k+min(i, m):(i+1)*k+min(i+1, m)] for i in range(n))

#add a translated column (of the col_name given) to the dataframe
def translate_freebase_df(df, col_name) :
    li = list(set(df[col_name].dropna().tolist()))
    di = dict()
    for l in split(li, 10) :
        di.update(translate_freebase_list(l))

    df[col_name + '_translated'] = df[col_name].apply(lambda x : di[x] if x in di else np.NaN)
    return df

# %% [markdown]
# ### 2.2 Example
# Below we run the `translate_freebase_df` on the characters metadata to retrieve their ethnicity.

# %%
translated_characters_df = character_metadata.copy()
translate_freebase_df(translated_characters_df, 'actor_ethnicity')

#print only rows where actor ethnicity is not null
translated_characters_df[['wikipedia_movie_id', 'actor_name', 'actor_ethnicity', 'actor_ethnicity_translated']].\
    loc[translated_characters_df['actor_ethnicity'].notna()].dropna().head(n=5)
# Out:
#     wikipedia_movie_id       actor_name actor_ethnicity  \
# 2               975900         Ice Cube         /m/0x67
# 5               975900        Pam Grier         /m/0x67
# 11              975900  Rodney A. Grant       /m/064b9n
# 27             3196793      Albert Hall         /m/0x67
# 55             2314463       Seth Green        /m/041rx
#
#    actor_ethnicity_translated
# 2           African Americans
# 5           African Americans
# 11               Omaha people
# 27          African Americans
# 55              Jewish people

# %% [markdown]
# # 3. Initial observations

# %% [markdown]
# Let's begin with some analysis. For that we are going to need the ratio of women actors per movie.

# %%
movie_gender = character_metadata.groupby(['wikipedia_movie_id', 'actor_gender']).size().unstack(fill_value=0)
movie_gender['ratio'] = movie_gender['F'] / (movie_gender['M'] + movie_gender['F'])
movie_gender = movie_gender['ratio'].reset_index()

# %% [markdown]
# We are going to plot the ratio of female actors in movie over the years.
#
# We can see that the ratio increases from 1940 to date but still remains below 0.37 which is intriguing. There is also an interesting period between 1920 and 1940 where the ratios are relatively high, it goes around 0.37, can we maybe link it to the particular history in those times ? We will continue those analysis in milestone 3.

# %%
#merge the movie dates using wikipedia ids
movie_gender_date = pd.merge(movie_gender, movie_metadata[['wikipedia_movie_id', 'movie_release_date']], on='wikipedia_movie_id').dropna()
movie_gender_date['year'] = pd.DatetimeIndex(movie_gender_date['movie_release_date']).year.astype('int')

#group the movies by year and drop years with less than 275 movies
movie_gender_date = movie_gender_date[movie_gender_date.groupby('year')['year'].transform('size') >= 275].\
    groupby('year')['ratio'].mean().reset_index()

#plot the graph
movie_gender_date.plot(x='year', y='ratio', kind='line', title='Ratio of female actors in movies');

# %% [markdown]
# # 4. Additional dataset

# %% [markdown]
# One additional that we are going to use is the collection of the plot summaries, run through the Stanford CoreNLP pipeline (tagging, parsing, NER and coref).
#
# This dataset will be useful to help us understand the role of female characters in the different movies.
#
# We are using the Element Tree module to parse the XML data.

# %%
DATA = '../corenlp_plot_summaries/'

def parse_nlp(id) -> ET :
    try:
        tree = ET.parse(DATA + str(id) + '.xml')
        return tree.getroot()
    #It is quite common that some ids do not have a corresponding xml file
    except FileNotFoundError:
        return 'FileNotFoundError'

# %% [markdown]
# ### 4.1 Example of the use of the core NLP
#
# Let's see how useful the core NLP dataset can be useful
#
# We use the core NLP dataset on the character Batman. We will collect information into the dictionary `batman_words` from all plot summaries of movies with the character batman.

# %%
#Let's get all the movies with batman
movies_with_batman = character_metadata['wikipedia_movie_id'].loc[character_metadata['character_name'] == 'Batman']
id_to_corenlp = {}

for id in movies_with_batman:
    id_to_corenlp[id] = parse_nlp(id)

# %%
#Make a dic of all the words linked to Batman during the movies
batman_words = dict()

for id in movies_with_batman:

    #Get the element tree root from the xml file
    root = id_to_corenlp[id]

    #Some movies do not have a corresponding xml file
    if root != 'FileNotFoundError':
        #Add all words to the dictionary
        for dep in root.findall("document/sentences/sentence/basic-dependencies/dep/[dependent='Batman']"):
            type = dep.attrib['type']
            if type not in batman_words:
                batman_words[type] = set()
            batman_words[type].add(dep.find('governor').text)

# %% [markdown]
# #### Character connected
#
# Spoiler alert ! We can see the connected characters to our batman in 'conj' (A conjunct is the relation between two elements connected by a conjunction word)
# We obviously see the Jocker or Bruce as a connected characters

# %%
print("Character connected : " + str(batman_words['conj']))
# Out:
# Character connected : {'Man', 'Owlman', 'Joker', 'Bruce', 'Princess'}

# %% [markdown]
# #### Nominal subject
# We can see Batman's actions using the nominal subject

# %%
print("Nominal subject : " + str(batman_words['nsubj']))
# Out:
# Nominal subject : {'continues', 'interrogates', 'tries', 'attempts', 'stands', 'disappeared', 'climb', 'menace', 'anticipated', 'inoculates', 'arrives', 'manages', 'knocks', 'appoints', 'alter', 'devises', 'rushes', 'decide', 'rescues', 'intimidates', 'throws', 'apprehends', 'stop', 'stops', 'win', 'finds', 'gives', 'expresses', 'has', 'get', 'works', 'interrogate', 'says', 'tackles', 'escapes', 'interrupts', 'comes', 'return', 'leaves', 'deduces', 'thinks', 'made', 'lets', 'foils', 'shows', 'locate', 'replies', 'stays', 'subdues', 'captures', 'recognizes', 'unhindered', 'responsible', 'destroys', 'outwits', 'pursues', 'takes', 'realizes', 'promises', 'asked', 'engage', 'defends', 'Bat-Signal', 'intervenes', 'uses', 'discovers', 'asks', 'go', 'heartbroken', 'sneaks', 'confronts', 'interrupting', 'reveals', 'intercepts', 'able', 'intends', 'hero', 'disarms', 'believes', 'declines', 'tells', 'strikes', 'convinces'}

# %% [markdown]
# # Testing

# %%
# using dictionary of English words tagged with their natural gender
# source : https://github.com/ecmonsen/gendered_words

url = 'https://raw.githubusercontent.com/ecmonsen/gendered_words/master/gendered_words.json'
tagged_words = pd.read_json(url)

# %%
WORDS_M = set(tagged_words[tagged_words.gender == 'm']['word'])
WORDS_F = set(tagged_words[tagged_words.gender == 'f']['word'])

# %%
def get_names_m_f(movie_id):
    names     = character_metadata[character_metadata.wikipedia_movie_id == movie_id][['character_name', 'actor_gender']]\
                .dropna()\
                .groupby('actor_gender')\
                .agg(' '.join)\
                .to_dict()['character_name']

    names_m   = set(names.get('M', '').lower().split(' '))
    names_f   = set(names.get('F', '').lower().split(' '))
    intersect = names_f.intersection(names_m)

    names_m   = names_m.difference(intersect)
    names_f   = names_f.difference(intersect)
    return names_m, names_f

# %%
def analyze_movie(movie_id, root):
    names_m, names_f = get_names_m_f(movie_id)

    actions_by_m = []
    actions_by_f = []
    actions_on_m = []
    actions_on_f = []
    descriptions_of_m = []
    descriptions_of_f = []

    if root != 'FileNotFoundError':
        for dep in root.iter('dep'):

            subject_name = dep[1].text.lower()
            action       = dep[0].text
            relation     = dep.attrib['type']

            if   subject_name in names_m or subject_name in WORDS_M :
                if   relation in {'nsubj'}:
                    actions_by_m     .append(action)
                elif relation in {'dobj', 'iobj'}:
                    actions_on_m     .append(action)
                elif relation in {'nmod', 'amod', 'nummod', 'appos'}:
                    descriptions_of_m.append(action)

            elif subject_name in names_f or subject_name in WORDS_F :
                if   relation in {'nsubj'}:
                    actions_by_f     .append(action)
                elif relation in {'dobj', 'iobj'}:
                    actions_on_f     .append(action)
                elif relation in {'nmod', 'amod', 'nummod', 'appos'}:
                    descriptions_of_f.append(action)

    new_row = {
        'actions by men'        : actions_by_m,
        'actions by women'      : actions_by_f,
        'actions on men'        : actions_on_m,
        'actions on women'      : actions_on_f,
        'descriptions of men'   : descriptions_of_m,
        'descriptions of women' : descriptions_of_f
    }
    return new_row

# %%
movie_ids = set(movie_metadata['wikipedia_movie_id'])

# %% [markdown]
# nlp_dict = {}
# for movie_id in movie_ids:
#     root = parse_nlp(movie_id)
#     if root != 'FileNotFoundError':
#         nlp_dict[movie_id] = analyze_movie(movie_id)
# movie_nlp = pd.DataFrame.from_dict(nlp_dict, orient='index')
# movie_nlp.index.name = 'movie_id'
# movie_nlp.to_csv(PROCESSED_DATA_FOLDER + 'movie_nlp.csv')

# %%
movie_nlp = pd.read_csv(PROCESSED_DATA_FOLDER + 'movie_nlp.csv', index_col='movie_id', dtype={'movie_id' : int},
                            converters={'actions by men'      : literal_eval, 'actions by women'      : literal_eval,
                                        'actions on men'      : literal_eval, 'actions on women'      : literal_eval,
                                        'descriptions of men' : literal_eval, 'descriptions of women' : literal_eval})

# %%
nlp_descriptions = ['actions by men', 'actions by women', 'actions on men', 'actions on women', 'descriptions of men', 'descriptions of women']
nlp_number_descriptions = ['number of ' + d for d in nlp_descriptions]
actions = ['actions by men', 'actions by women', 'actions on men', 'actions on women']

# %%
for i in range(6):
    movie_nlp[nlp_number_descriptions[i]] = movie_nlp[nlp_descriptions[i]].apply(len)

# %%
for desc in nlp_descriptions:
    movie_nlp[desc + ' unique'] = movie_nlp[desc].apply(np.unique)

# %%
movie_metadata_nlp = movie_metadata[['wikipedia_movie_id', 'movie_release_year']].dropna()\
    .merge(movie_nlp, left_on='wikipedia_movie_id', right_on='movie_id')

# %%
movie_metadata_nlp['decade_released'] = movie_metadata_nlp['movie_release_year'].apply(lambda year : math.floor(year/10) * 10)

# %%
b = pd.DataFrame(movie_metadata_nlp[['decade_released'] + nlp_number_descriptions].groupby('decade_released').agg(np.sum))

# %%
(b['number of actions on women'] / b['number of actions by women']).plot()
(b['number of actions on men']   / b['number of actions by men'])  .plot();

# %%
(b['number of actions on women'] / b['number of actions on men']).plot()
(b['number of actions by women'] / b['number of actions by men']).plot();

# %%
((b['number of actions on women'] + b['number of actions by women']) / (b['number of actions on men'] + b['number of actions by men'])).plot();

# %% [markdown]
# actions

# %%
def f(x, word):
    y = list(np.hstack(x))
    l = len(y)
    return 0 if l==0 else y.count(word)/len(y)

# %% [markdown]
# meets, gives,
# kill, kills, shoot,
# marry, loves,
# save

# %%
a = movie_metadata_nlp[['decade_released'] + actions].groupby('decade_released').agg(lambda x : f(x, 'refuses'))
a.plot();

# %%
def sort_by_freq(x):
    words, freq = np.unique(np.hstack(x), return_counts=True)
    sorted_indexes = np.argsort(freq)[::-1]
    sorted_by_freq = words[sorted_indexes]
    return sorted_by_freq

# %%
res = np.empty(0)
for x in actions:
    y = np.hstack(movie_metadata_nlp[x])
    res = np.append(res, y)

# %%
most_frequents = sort_by_freq(res)

# %%
total_actions = movie_metadata_nlp[actions].applymap(len).apply(sum)

# %%
dico = {}
for w in most_frequents[:50]:
    a = movie_metadata_nlp[actions].applymap(lambda bow : False if len(bow)==0 else w in bow) / total_actions
    dico[w] = [stats.ttest_ind(a['actions by men'], a['actions by women'])[1],
               stats.ttest_ind(a['actions on men'], a['actions on women'])[1]]

# %%
pd.DataFrame.from_dict(dico, orient='index')
# Out:
#                       0             1
# tells      4.978684e-30  1.891206e-01
# finds      9.834930e-02  1.348579e-03
# has        2.380590e-01  1.785273e-10
# meets      5.828615e-02  1.192622e-57
# takes      1.414599e-05  1.898523e-12
# is         8.141394e-07  1.557535e-01
# goes       8.020326e-04  4.862388e-01
# asks       2.469390e-05  1.762205e-03
# sees       3.095789e-01  1.525480e-11
# tries      2.366566e-01  8.208716e-04
# leaves     1.362285e-22  1.349551e-03
# gives      6.212929e-06  3.443457e-54
# kill       1.985004e-21  5.052514e-10
# decides    6.969532e-02  3.994425e-01
# find       3.649087e-02  4.006693e-10
# kills      2.872562e-46  1.800773e-21
# wants      3.895206e-04  9.124182e-03
# gets       1.369762e-10  6.391319e-01
# take       1.047875e-02  4.093639e-06
# discovers  2.964224e-03  2.664630e-02
# comes      7.771856e-01  4.131911e-01
# realizes   7.290705e-04  1.491290e-01
# marry      2.652359e-41  9.128137e-51
# begins     1.843062e-03  8.662045e-01
# says       6.136024e-05  9.600077e-01
# have       1.519443e-07  5.985943e-02
# arrives    1.315021e-03  6.703888e-01
# go         1.214096e-08  3.986332e-01
# refuses    1.550248e-12  1.761754e-01
# falls      6.975115e-03  1.865000e-03
# loves      5.058562e-18  1.855967e-26
# leave      4.439178e-09  4.615464e-05
# see        3.319093e-06  1.440190e-10
# returns    2.100993e-04  3.234035e-02
# reveals    2.460085e-02  1.559825e-03
# calls      9.873995e-01  2.020894e-01
# makes      4.459623e-02  9.046970e-01
# get        5.042009e-01  4.614096e-04
# learns     1.563523e-02  4.325636e-01
# runs       4.821075e-15  8.423253e-01
# shoots     3.849113e-11  2.041533e-52
# confronts  8.356781e-01  3.933594e-03
# had        3.954539e-07  7.500687e-03
# tell       2.779559e-05  2.732694e-01
# meet       3.820527e-05  1.140107e-02
# agrees     1.417691e-04  8.320519e-01
# named      8.954442e-02  2.147029e-06
# killed     6.314168e-19  5.419085e-01
# informs    5.555420e-01  4.659177e-08
# give       7.731742e-01  1.375583e-27

# %%
dico = {}
for w in most_frequents[:50]:
    dico[w] = [f(movie_metadata_nlp['actions by men'], w) / f(movie_metadata_nlp['actions by women'], w),
               f(movie_metadata_nlp['actions on men'], w) / f(movie_metadata_nlp['actions on women'], w)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [405], line 4
#       1 dico = {}
#       2 for w in most_frequents[:50]:
#       3     dico[w] = [f(movie_metadata_nlp['actions by men'], w) / f(movie_metadata_nlp['actions by women'], w),
# ----> 4                f(movie_metadata_nlp['actions on men'], w) / f(movie_metadata_nlp['actions on women'], w)]
#
# Cell In [397], line 2, in f(x, word)
#       1 def f(x, word):
# ----> 2     y = list(np.hstack(x))
#       3     l = len(y)
#       4     return 0 if l==0 else y.count(word)/len(y)
#
# File <__array_function__ internals>:5, in hstack(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/numpy/core/shape_base.py:338, in hstack(tup)
#     334 if not overrides.ARRAY_FUNCTION_ENABLED:
#     335     # raise warning if necessary
#     336     _arrays_for_stack_dispatcher(tup, stacklevel=2)
# --> 338 arrs = atleast_1d(*tup)
#     339 if not isinstance(arrs, list):
#     340     arrs = [arrs]
#
# File <__array_function__ internals>:5, in atleast_1d(*args, **kwargs)
#
# File /usr/lib/python3/dist-packages/numpy/core/shape_base.py:65, in atleast_1d(*arys)
#      63 res = []
#      64 for ary in arys:
# ---> 65     ary = asanyarray(ary)
#      66     if ary.ndim == 0:
#      67         result = ary.reshape(1)
#
# KeyboardInterrupt:

# %%
pd.DataFrame.from_dict(dico, orient='index')
# Out:
#                   0         1
# tells      0.777033  1.028820
# finds      0.992855  0.884187
# has        1.027927  0.677125
# meets      1.097880  0.506636
# takes      1.231401  0.721601
# is         0.902519  0.413395
# goes       0.923531  0.862160
# asks       0.887352  0.832692
# sees       1.038710  0.654626
# tries      1.132668  0.312651
# leaves     0.750701  1.242115
# gives      0.838628  2.273775
# kill       2.012598  1.376404
# decides    0.973705  1.517401
# find       1.268824  0.747769
# kills      2.407370  1.745716
# wants      0.900921  0.703987
# gets       1.241070  0.934480
# take       1.238622  0.803458
# discovers  0.916763  0.708253
# comes      1.028984  0.820366
# realizes   0.909849  0.614333
# marry      0.395639  0.467375
# begins     0.927960  0.979641
# says       0.862229  1.010105
# have       0.883423  0.862346
# arrives    1.226893  1.103868
# go         0.873376  0.830299
# refuses    0.778278  0.666990
# falls      0.902940  0.357465
# loves      0.614583  0.518117
# leave      0.796578  1.283842
# see        0.748076  0.731159
# returns    1.217403  0.629935
# reveals    0.955364  1.707349
# calls      1.031615  0.924707
# makes      1.156518  0.973686
# get        1.129516  0.807317
# learns     1.141423  0.789598
# runs       0.710419  1.101472
# shoots     1.676506  3.090822
# confronts  1.039117  1.242005
# had        0.824353  0.676504
# tell       0.741711  0.980034
# meet       0.924111  0.890585
# agrees     0.874003  0.924059
# named      0.759090  0.846635
# killed     1.893885  1.055052
# informs    1.001035  1.485202
# give       1.011020  2.029762

# %%
dico = {}
for d in nlp_descriptions:
    dico[d] = sort_by_freq(movie_metadata_nlp[d])[:20]

# %%
#pd.DataFrame.from_dict(dico, orient='index')

# %%
a = movie_metadata_nlp['actions by women'].apply(lambda l : 1 if 'marry' in l else 0)

# %%
np.sum(a)
# Out:
# 579
